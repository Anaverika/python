# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_excel('P1-Airline-Comparison.xlsx')

# %%
df1=pd.read_excel('P1-SuperStoreUS-2015.xlsx')

# %%
df1.iplot()
# Out:
# <div>                            <div id="af88ba4c-d23d-4938-9bb5-a18cb67ca562" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#    Period         Region    Revenue
# 0  FY2015         Africa   10000000
# 1  FY2015           Asia   20000000
# 2  FY2015      Australia   70000000
# 3  FY2015         Europe  120000000
# 4  FY2015  North America  150000000

# %%
df.iplot(kind='scatter',x='Region',y='Revenue')
# Out:
# <div>                            <div id="7fc2df78-e7ca-4083-8292-b1225857306c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bar',x='Region',y='Revenue')
# Out:
# <div>                            <div id="e38d6f08-6283-4b4a-948c-34aaa02b6f67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="5183c64d-af83-4d65-ae4d-d45028010471" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.sort_values(by='Region',ascending=False)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 722    18693       Critical      0.04        2.52           1.92         1257
# 652    24225       Critical      0.08       15.04           1.97         1155
# 661    19484           High      0.07        2.61           0.50         1182
# 662    21522  Not Specified      0.04       35.99           3.30         1183
# ...      ...            ...       ...         ...            ...          ...
# 1491   18623         Medium      0.02       30.53          19.99         2628
# 1492   21981       Critical      0.01      194.30          11.54         2630
# 1493   21982       Critical      0.02      209.84          21.21         2630
# 1494   21983       Critical      0.00      145.45          17.85         2630
# 1150   20500  Not Specified      0.00       10.31           1.79         2072
#
# ...

# %%
dfb=df1[df1['Region']=='Central'][['Shipping Cost','Unit Price']].head(10)

# %%
dfb
# Out:
#     Shipping Cost  Unit Price
# 3           19.99       78.69
# 4            2.31        3.28
# 5            4.20        3.28
# 6            1.63        3.58
# 31           5.15        5.98
# 32           4.86       29.14
# 53          30.00      160.98
# 54           4.00       17.98
# 55          30.00      160.98
# 56           8.99      115.99

# %%
dfb.iplot(kind='box')
# Out:
# <div>                            <div id="f6c9b75f-5782-4a56-89a1-52c459f45eba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
dfb.iplot(kind='surface')
# Out:
# <div>                            <div id="8920616b-c990-4a79-bb84-41bab853200f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
dfb.iplot(kind='hist')
# Out:
# <div>                            <div id="4ef980ad-157d-41b1-8377-4fe1cc82e330" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1[['Unit Price','Shipping Cost']].iplot(kind='spread')
# Out:
# <div>                            <div id="79f06480-dbeb-46aa-b95a-8f11295d45f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
